# %%
import numpy as np

# %%
taxi= np.genfromtxt('nyc_taxis.csv',delimiter=',', skip_header= True)

# %%
speed= taxi[:,7]/(taxi[:,8]/3600)

# %%
mean_speed= speed.mean()
mean_speed
# Out:
# np.float64(32.24258580925573)

# %% [markdown]
# total no of rides in month of feburary

# %%
taxi[taxi[:,1]==2,1]
# Out:
# array([2., 2., 2., ..., 2., 2., 2.], shape=(13333,))

# %% [markdown]
# no of rides tip amount> 50

# %%
taxi[taxi[:,11]>50,11]
# Out:
# array([ 80.  ,  55.41, 400.54, 805.54, 101.08, 135.84])

# %%
print(tip.shape[0])
# Out:
# 16

# %% [markdown]
# drop off location is 2

# %%
taxi[taxi[:,6]==2,6]
# Out:
# array([2., 2., 2., ..., 2., 2., 2.], shape=(11832,))
